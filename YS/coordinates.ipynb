# %% [markdown]
# <a href="https://colab.research.google.com/github/jl749/CJ_VRP/blob/master/YS/coordinates.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import folium
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#위도 경도 읽어오기 .excel 파일 
#아래 데이터는 임의 테스트용 데이터 
coordinates_data = pd.read_excel('/content/drive/MyDrive/CJ/화성시 좌표 데이터(test).xlsx')
#coordinates_data = pd.read_excel('파일 이름')


#위도 경도 읽어오기 .csv 파일 
#coordinates_data = pd.read_csv('파일 이름')

# %%
def Delivery_address_marker(map,data):
  #택배지 위도 경도 데이터를 지도에 시각화 
  for ma in range(data.shape[0]):
    folium.Marker(location = [data['위도'][ma],data['경도'][ma]],popup = '택배' + str(ma) + '주소').add_to(map)

# %%
#지도의 처음 위치 찍기 -> 화성이랑 제일 가까운 CJ 물류 센터로 선택 
# map = folium.Map(location = [물류센터의 위도 , 물류센터의 경도],zoom_start=13)
map = folium.Map(location = [37.33507198212856, 126.7140465554204],zoom_start=13)


#물류센터 출발지 marker 로 표시
#start = folium.Marker(location = [물류센터의 위도 , 물류센터의 경도],popup="물류센터",icon=folium.Icon(color="red", icon="info-sign") ).add_to(map) 
start = folium.Marker(location = [37.33507198212856, 126.7140465554204],popup="물류센터",icon=folium.Icon(color="red", icon="info-sign") ).add_to(map)

Delivery_address_marker(map,coordinates_data)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...
